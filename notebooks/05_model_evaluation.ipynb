# %%
baseline_results = evaluate_model(
    baseline,
    X_test_scaled,
    y_test
)

pd.DataFrame(
    baseline_results.items(),
    columns=["Metric", "Value"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 baseline_results = evaluate_model(
#       2     baseline,
#       3     X_test_scaled,
#       4     y_test
#
# NameError: name 'evaluate_model' is not defined
